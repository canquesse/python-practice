# %% [markdown]
# # Comparing
# A short Python fundamentals exercise. Run the cells in order.

# %%
print(5 < 2)

# %%
print("can" == "Can")

# %%
print(83 != 82)

# %%
# Python does not implicitly mix numbers and strings.
try:
    2 < "2"
except TypeError as error:
    print(f"Expected TypeError: {error}")

# %%
print("Blue" > "AmaninBow" and 999 > 3*333)

# %%
print("Blue" > "AmaninBow" or 999 > 3*333)
