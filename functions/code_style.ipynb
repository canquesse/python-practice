# %% [markdown]
# # Code Style
# A short Python fundamentals exercise. Run the cells in order.

# %%
def calculate(d):
    q = 3.14
    z = q * (d ** 2)
    print (z)

# %%
calculate(14)

# %%
def circle_area(radius):
    pi = 3.14
    area = pi * (radius ** 2)
    print(area)

# %%
circle_area(85)
